# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Qinwen Zheng"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Quiz 1 (each question is worth 2 points)
#
# **COMPSCI 101, Duke Kunshan University**

# %% [markdown]
# ### Attention: Please delete all incorrect options below so that you have a single line that represents your final answer. Also please delete all raise NotImplementedError()!

# %% [markdown]
# ## Q1
# #### What is the value range of an 8-bit unsigned integer? (All ranges are inclusive)

# %%
#Note: please delete all incorrect options below so that you have a single line that represents your final answer
ans1 = '0-255'

# %%
# There is a hidden test here

# %% [markdown]
# ## Q2
# #### Which one of the following is the closest binary approximation of decimal number 59.2.

# %%
#Note: please delete all incorrect options below so that you have a single line that represents your final answer
ans2 = '111011.0011'

# %%
# There is a hidden test here

# %% [markdown]
# ## Q3
# #### Calculate the bitrate (in bits per second) of an Apple Music Hi-Res Lossless audio stream recorded at:
# 	•	24-bit depth
# 	•	192 kHz sampling rate
# 	•	8 audio channels (Dolby Atmos)
# #### Assume no compression is applied, which of the following is correct?

# %%
#Note: please delete all incorrect options below so that you have a single line that represents your final answer
ans3 = '24*192000*8'

# %%
# There is a hidden test here

# %% [markdown]
# ## Q4
# #### Which type of memory does the CPU directly interact with during processing?

# %%
#Note: please delete all incorrect options below so that you have a single line that represents your final answer
ans4 = 'RAM'

# %%
# There is a hidden test here

# %% [markdown]
# ## Q5
# A CRIS hyperspectral satellite image has a spatial resolution of 1200 × 1200 pixels and contains 700 spectral channels. Each pixel value in every channel is stored using 16 bits. If the image is transmitted over an internet connection with a speed of 100 Mbps, calculate how long (in seconds) it would take to download the entire image. Assume no compression, which of the following is correct?

# %%
ans5 = '1200*1200*700*16/(100*10^6)'

# %%
# There is a hidden test here

# %% [markdown]
# ## Q6
# #### Perform the binary subtraction: $11010000_{2} - 101011_{2}$
# #### Which one is correct?

# %%
#Note: please delete all incorrect options below so that you have a single line that represents your final answer
ans6 = '10100101'

# %%
# There is a hidden test here

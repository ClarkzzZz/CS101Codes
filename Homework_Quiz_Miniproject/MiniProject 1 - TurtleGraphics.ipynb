# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Qinwen Zheng"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # MiniProject 1
# **COMPSCI 101, Duke Kunshan University**

# %% [markdown]
# ## Important
#
# All the work for this project must be done on your **local computer**. But your finished code must be submitted to the JP Server through the final cell below!

# %% [markdown]
# ## Caution!
# Your must program the **codes by yourself!** After submission of the project, we may pick up some students to explain how their codes have produced the graphics/images submitted, line by line! You will **bear the consequence** if you fail to explain or have obvious difficulty to do so!

# %% [markdown]
# ## Task

# %% [markdown]
# ### Step 1:
#
# You're required to create a graphics using the `turtle` library. Your image/graphics must meet the following **requirements**:
# - It consists of at least **3 distinct elements**, for instance, `line, triangle, circle`.
# - It must be about **YOU**, such as your name, birth place/town, hobby, major and favorite food. You may be asked to present the image and explain.
# - It cannot be directly downloaded online. This is cheating!
#
# Below are some sample images that may give you ideas - your graphics does not have to be complex - you can be more creative!
#
# <img src='referenceImages-forMiniP01.png' style='width: 400px; float:left; margin-right: 15px'>

# %% [markdown]
# ### Codes for the images above
#
# You may have a look at the codes to see how the images are drawn. **Note that** after the graphics is shown, the window may hang (is not responding) when you try closing it. If this happens, 'kill' the program through 'Task Manager' in Widnows System or similar approach in Mac.

# %% [markdown]
# #### Code 1 - the top left image above

# %%
# YOUR CODE HERE
import turtle as t
import importlib
importlib.reload(t)
#cartoon mouse
i=120
s=50
t.speed(15)
t.pensize(2)
#ears
for j in range (2):
    t.penup()
    t.goto(-i,150)
    t.pendown()
    t.color('black', 'light grey')
    t.begin_fill()
    t.circle(60)
    t.end_fill()
    t.penup()
    t.goto(-i,175)
    t.pendown()
    t.color('black', 'white')
    t.begin_fill()
    t.circle(30)
    t.end_fill()
    i=-i
#face    
t.penup()
t.goto(-87,160)
t.pendown()
t.color('grey', 'light grey')
t.begin_fill() 
for i in range(2):
    t.forward(175)
    t.right(90)
    t.forward(150)
    t.right(90)
t.end_fill()

t.penup()
t.goto(-87,80)
t.pendown()
t.forward(175)
#eyes
for j in range (2):
    t.penup()
    t.goto(-s,90)
    t.pendown()
    t.color('black', 'grey')
    t.begin_fill()
    t.circle(30)
    t.end_fill()
    t.penup()
    t.goto(-(s-7),100)
    t.pendown()
    t.color('black', 'white')
    t.begin_fill()
    t.circle(17)
    t.end_fill()
    t.penup()
    t.goto(-(s-7),100)
    t.pendown()
    t.color('black')
    t.begin_fill()
    t.circle(10)
    t.end_fill()
    s=-s
#nose
t.penup()
t.goto(20,60)
t.pendown()
t.color('red', 'pink')
t.begin_fill()
for j in range (3):
    t.right(120)
    t.forward(30)
t.end_fill()
#mouth
t.penup()
t.goto(-15,20)
t.pendown()
t.color('red')
t.circle(50,50)

t.done()

# %% [markdown]
# #### Code 2 - the top right image above

# %%
import turtle as t
import importlib
importlib.reload(t)

t.color('black','DarkOliveGreen1')
t.penup()
t.shapesize(2,2,2)
t.goto(160,-25)
t.pensize(3)

#first circle
t.pendown()
t.begin_fill()
t.circle(40)
t.end_fill()
t.penup()

#second circle
t.bk(70)
t.rt(90)
t.fd(10)
t.lt(90)
t.pendown()
t.begin_fill()
t.circle(40)
t.end_fill()
t.penup()

#third circle
t.bk(70)
t.lt(90)
t.fd(10)
t.rt(90)
t.pendown()
t.begin_fill()
t.circle(40)
t.end_fill()
t.penup()

# fourth circle
t.bk(70)
t.rt(90)
t.fd(10)
t.lt(90)
t.pendown()
t.begin_fill()
t.circle(40)
t.end_fill()
t.penup()

# head circle
t.bk(70)
t.lt(90)
t.fd(30)
t.rt(90)
t.pendown()
t.begin_fill()
t.circle(40)
t.end_fill()
t.penup()

# to draw first antenna
t.lt(90)
t.fd(60)
t.lt(90)
t.fd(20)
t.rt(60)
t.fd(5)
t.pendown()
t.fd(50)

# to draw first star
t.penup()
t.rt(30)
t.bk(10)
t.color('yellow','yellow')
t.pendown()
t.begin_fill()
for i in range(5):
    t.fd(25)
    t.rt(144)    
t.end_fill()
t.penup()

# to draw the second antenna
t.color('black')
t.fd(10)
t.lt(30)
t.bk(50)
t.rt(120)
t.fd(40)
t.lt(60)
t.pendown()
t.fd(50)
t.end_fill()
t.penup()

# to draw the second star
t.lt(30)
t.bk(10)
t.color('yellow','yellow')
t.pendown()
t.begin_fill()
for i in range(5):
    t.fd(25)
    t.rt(144)

    
t.end_fill()
t.penup()

# to draw the smile
t.color('black')
t.bk(70)
t.lt(90)
t.fd(60)
t.lt(120)
t.pendown()
t.circle(20,135)
t.penup()

# eyes
t.lt(60)
t.fd(15)

t.dot(10)
t.penup()

t.lt(30)
t.lt(10)
t.fd(15)

t.dot(10)
t.penup()
t.home()

# to draw tail
t.goto(160,-25)
t.circle(40,120)
t.color('cornsilk','cornsilk')
t.dot(40)
t.color('black','DarkOliveGreen1')
t.goto(160,-25)
t.rt(120)
t.pendown()
t.begin_fill()
t.circle(40)
t.end_fill()
t.penup()

# to draw legs
t.rt(90)
t.color('black','brown')

# leg 1
t.pendown()
t.fd(20) # repetition for each leg starts
t.dot(15)
t.penup() # repetition ends
t.goto(90,-35)

# leg 2
t.pendown()
t.fd(20)
t.dot(15)
t.penup()
t.goto(20,-25)

#leg 3
t.pendown()
t.fd(20)
t.dot(15)
t.penup()
t.goto(-50,-35)

#leg 4
t.pendown()
t.fd(20)
t.dot(15)
t.penup()

#leg 5
t.bk(25)
t.rt(90)
t.fd(32)
t.lt(90)
t.bk(10)
t.pendown()
t.fd(25)
t.dot(15)
t.penup()

#leg 6
t.goto(-12,-10)
t.pendown()
t.fd(25)
t.dot(15)
t.penup()

#leg 7
t.goto(58,-20)
t.pendown()
t.fd(25)
t.dot(15)
t.penup()

#leg 8
t.goto(128,-10)
t.pendown()
t.fd(25)
t.dot(15)
t.penup()

t.done

# %% [markdown]
# #### Code 3 - the bottom left image above

# %%
# YOUR CODE HERE
import turtle as t
import importlib
importlib.reload(t)

t.speed(100)

t.color('black', 'red')
t.penup()
t.goto(-6,78)
t.pendown()
t.begin_fill()

t.circle(40,40)
t.circle(40,-80)

t.left(180)

t.circle(92,100)

t.circle(210,85)
t.circle(40,80)

t.left(180)
t.circle(70,-90)

t.left(180)
t.circle(40,80)
t.circle(210,35)

t.left(270)
t.circle(80,-140)

t.left(-90)
t.circle(210,7)

t.circle(92,108)

t.end_fill()

t.penup()
t.goto(-6,110)
t.seth(-80)

t.color('black', 'red')

t.pendown()
t.begin_fill()

t.circle(70,-100)
t.right(78)
t.circle(70,-100)

t.end_fill()

t.penup()
t.goto(-20,0)
t.seth(-150)

t.color('black', 'white')

t.pendown()
t.begin_fill()

t.circle(50,-300)
t.right(240)
t.circle(50,-300)
t.end_fill()

t.penup()
t.goto(-75,0)

t.color('black', 'brown')
t.pendown()
t.begin_fill()
t.circle(15)
t.end_fill()

t.penup()
t.goto(0,-40)

t.color('black', 'brown')

t.pendown()
t.begin_fill()

t.circle(15)
t.end_fill()

t.penup()
t.goto(20,-100)

t.color('black', 'brown')

t.pendown()
t.begin_fill()

t.circle(70,-180)
t.end_fill()

t.done()

# %% [markdown]
# #### Code 4 - the bottom right image above

# %%
import turtle as t
import importlib
importlib.reload(t)

t.title('The Mushroom House')
t.bgcolor('green')
t.pencolor('black')
t.pensize(3)
t.fillcolor('yellow')
t.begin_fill()
t.speed(16)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.right(90)
t.forward(100)
t.end_fill()

t.begin_fill()
t.goto(-50,0)
t.left(180)
t.pencolor('black')
t.fillcolor('red')
t.circle(100,-180)
t.left(90)
t.goto(-50,0)
t.end_fill()

t.penup()

t.goto(20,20)
t.pendown()
t.color('white')
t.dot(20)

t.penup()

t.goto(70,30)
t.pendown()
t.color('white')
t.dot(20)

t.penup()

t.goto(45,70)
t.pendown()
t.color('white')
t.dot(20)

t.penup()

t.goto(110,40)
t.pendown()
t.color('white')
t.dot(20)

t.penup()

t.goto(-20,30)
t.pendown()
t.color('white')
t.dot(20)

t.penup()

t.goto(20,-100)
t.pendown()
t.pencolor('black')
t.fillcolor('purple')
t.begin_fill
t.setheading(90)
t.forward(50)
t.setheading(0)
t.forward(25)
t.setheading(270)
t.forward(50)
t.setheading(180)
t.forward(10)
t.end_fill

t.penup()

t.goto(30,-75)
t.pensize(1)
t.fillcolor('gold')
t.pendown()
t.setheading(270)
t.forward(10)
t.setheading(150)
t.forward(10)
t.setheading(30)
t.forward(10)


t.penup()

t.pensize(3)
t.goto(60,-40)
t.pendown()
t.fillcolor('deepskyblue')
t.begin_fill()
t.setheading(90)
t.forward(25)
t.setheading(0)
t.forward(25)
t.setheading(270)
t.forward(25)
t.setheading(180)
t.forward(25)
t.end_fill()

t.penup()

t.pensize(2)
t.goto(72.5,-40)
t.pendown()
t.setheading(90)
t.forward(25)

t.penup()

t.goto(60,-27.5)
t.pendown()
t.setheading(0)
t.forward(25)

t.done

# %% [markdown]
# ### Step 2:
#
# After you finish your turtle graphic, take a `screen shot` of your screen and crop the relevant portion of the screen and save the resulting image. The type of your image file can be `.png` or `.jpg`
#
# **Filename**: make sure the name of your file is your **net id**. For instance, my file should be named as `ft47.jpg` or `ft47.png`
#
# To submit your image, please follow the instruction in Ed.

# %% [markdown]
# ### Step 3:
#
# Describe below how your turtle graphics is related to YOU. The description must be no less than 30 words.

# %%
#I drew this "Sweat Smile" because since entering session 2 recently, I have been under a lot of study pressure. This expression precisely reflects my current mental state and the consistent facial expression I've had during the seven-week study period. XD

# %% [markdown]
# ### Step 4:
#
# Add your codes that produce the image you submitted to Ed, and then submit this mini-project to the JP server

# %%
import turtle as t
import importlib
importlib.reload(t)

t.speed(1000)
t.setup(800, 800)
t.pu()

#face
t.color("Goldenrod", "Gold")
t.pensize(15)
t.goto(0, -300)
t.pd()
t.begin_fill()
t.circle(300, 360)
t.end_fill()
t.pu()

#left eye
t.color("DarkGoldenrod")
t.pensize(1)
t.goto(-150, 0)
t.pd()
t.begin_fill()
t.right(90)
t.circle(50,-180)
t.pu()
t.goto(-150, 0)
t.pd()
t.fd(50)
t.left(180)
t.circle(50,-180)
t.bk(50)
t.end_fill()
t.pu()

#right eye
t.color("DarkGoldenrod")
t.pensize(1)
t.goto(50, 0)
t.pd()
t.begin_fill()
t.left(180)
t.circle(50,-180)
t.pu()
t.goto(50, 0)
t.pd()
t.fd(50)
t.left(180)
t.circle(50,-180)
t.bk(50)
t.end_fill()
t.pu()

#mouth
t.color("DarkGoldenrod")
t.pensize(1)
t.goto(200, -50)
t.pd()
t.begin_fill()
t.circle(200, -180)
t.left(66)
t.circle(500, 48)
t.end_fill()
t.pu()

#teeth
t.color("white")
t.pensize(1)
t.goto(-180,-70)
t.pd()
t.begin_fill()
t.right(45)
t.circle(500, 43)
t.right(120)
t.fd(40)
t.left(119)
t.circle(500, -42)
t.left(119)
t.fd(42)
t.end_fill()
t.pu()

#sweat
t.goto(200, 300)
t.right(9)
t.pensize(1)
t.color("CornflowerBlue")
t.pd()
t.begin_fill()
t.left(162)
t.fd(200)
t.left(108)
t.fd(200 * ( 5**0.5 - 1 )/2)
t.left(108)
t.fd(200)
t.end_fill()
t.pu()
t.goto(400, 400)

t.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[1], line 5
#       2 import importlib
#       3 importlib.reload(t)
# ----> 5 t.speed(1000)
#       6 t.setup(800, 800)
#       7 t.pu()
#
# File <string>:6, in speed(speed)
#
# File /home/conda3/envs/env1/lib/python3.13/turtle.py:3844, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3839 def __init__(self,
#    3840              shape=_CFG["shape"],
#    3841              undobuffersize=_CFG["undobuffersize"],
#    3842              visible=_CFG["visible"]):
#    3843     if Turtle._screen is None:
# -> 3844         Turtle._screen = Screen()
#    3845     RawTurtle.__init__(self, Turtle._screen,
#    3846                        shape=shape,
#    3847                        undobuffersize=undobuffersize,
#    3848                        visible=visible)
#
# ...
